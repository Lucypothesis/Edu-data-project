# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# macOS 기본 한글 폰트 설정 (AppleSDGothicNeo 등)
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
path = '/Users/yniyunj/Desktop/교육공공데이터/데이터/004-특색사업수/'

df24 = pd.read_csv(path + '2024년도_교육운영 특색사업 계획(초)_전체.csv', encoding = 'utf-8')

# %%
df24
# Out:
#            시도교육청           교육지원청           지역   정보공시 학교코드              학교명  \
# 0       서울특별시교육청  서울특별시강남서초교육지원청    서울특별시 서초구  S000003511    서울교육대학교부설초등학교
# 1       서울특별시교육청    서울특별시중부교육지원청    서울특별시 종로구  S000003563  서울대학교사범대학부설초등학교
# 2       서울특별시교육청  서울특별시강남서초교육지원청    서울특별시 강남구  S010000737         서울개원초등학교
# 3       서울특별시교육청  서울특별시강남서초교육지원청    서울특별시 강남구  S010000738         서울개일초등학교
# 4       서울특별시교육청  서울특별시강남서초교육지원청    서울특별시 강남구  S010000739         서울개포초등학교
# ...          ...             ...          ...         ...              ...
# 6297  제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000801           월랑초등학교
# 6298  제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000834           이도초등학교
# 6299  제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000836           도련초등학교
# 6300  제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000837           삼화초등학교
# 6301  제주특별자치도교육청        제주시교육지원청  제주특별자치도 제주시  S170000839          하귀일초등학교
#
#       학교급코드 설립구분 제외여부 제외사유 자율학교(지정·운영) 수준별 수업(운영)
# 0         2   국립    N  NaN           ○          ×
# 1         2   국립    N  NaN           ○          ×
# 2         2   공립    N  NaN           ×          ×
# 3         2   공립    N  NaN           ×          ×
# 4         2   공립    N  NaN           ×          ×
# ...     ...  ...  ...  ...         ...        ...
# 6297      2   공립    N  NaN           ×          ×
# 6298      2   공립    N  NaN           ×          ×
# 6299      2   공립    N  NaN           ×          ×
# 6300      2   공립    N  NaN           ×          ×
# 6301      2   공립    N  NaN           ×          ×
#
# [6302 rows x 11 columns]

# %%
for i in df24.columns:
    print(i)
# Out:
# 시도교육청
# 교육지원청
# 지역
# 정보공시 학교코드
# 학교명
# 학교급코드
# 설립구분
# 제외여부
# 제외사유
# 자율학교(지정·운영)
# 수준별 수업(운영)
